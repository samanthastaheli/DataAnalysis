# %% [markdown]
# # Amazon Books Dataset

# %%
import pandas as pd
import altair as alt

# %%
books = pd.read_csv("datasets/amazon_com_extras.csv")
books.head()
# Out:
#          ASIN GROUP     FORMAT  \
# 0  1250150183  book  hardcover
# 1   778319997  book  hardcover
# 2  1608322564  book  hardcover
# 3   310325331  book  hardcover
# 4   312616295  book  hardcover
#
#                                                TITLE  \
# 0  The Swamp: Washington's Murky Pool of Corrupti...
# 1            Rise and Shine, Benedict Stone: A Novel
# 2  Sell or Be Sold: How to Get Your Way in Busine...
# 3  Christian Apologetics: An Anthology of Primary...
# 4  Gravity: How the Weakest Force in the Universe...
#
#                                AUTHOR                   PUBLISHER Unnamed: 6  \
# 0                        Eric Bolling          St. Martin's Press        NaN
# 1                     Phaedra Patrick              Park Row Books        NaN
# 2                       Grant Cardone  Greenleaf Book Group Press        NaN
# 3  Khaldoun A. Sweis, Chad V. Meister                   Zondervan        NaN
# ...

# %%
books["Unnamed: 9"].value_counts()
# Out:
#  Black and Proud Blerd                                      1
#  Linda Barnes 'Ph.D.  M.A.                                  1
#  Preschool ... learn) (The Terry Treetop Series Book 1)'    1
#  Music                                                      1
# Brookes Publishing                                          1
# Name: Unnamed: 9, dtype: int64
